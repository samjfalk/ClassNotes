# %% [markdown]
# ##ORIGINALLY PULLED BY GregorUT
#
# from bs4 import BeautifulSoup
# import urllib
# import pandas as pd
#
# pages = 18
# rec_count = 0
# rank = []
# gname = []
# platform = []
# year = []
# genre = []
# publisher = []
# sales_na = []
# sales_eu = []
# sales_jp = []
# sales_ot = []
# sales_gl = []
#
# urlhead = 'http://www.vgchartz.com/gamedb/?page='
# urltail = '&results=1000&name=&platform=&minSales=0.01&publisher=&genre=&sort=GL'
#
# for page in range(1,pages):
# 	surl = urlhead + str(page) + urltail
# 	r = urllib.urlopen(surl).read()
# 	soup = BeautifulSoup(r)
# 	print page
# 	chart = soup.find("table", class_="chart")
# 	for row in chart.find_all('tr')[1:]:
# 		try:
# 			col = row.find_all('td')
#
# 			#extract data into column data
# 			column_1 = col[0].string.strip()
# 			column_2 = col[1].string.strip()
# 			column_3 = col[2].string.strip()
# 			column_4 = col[3].string.strip()
# 			column_5 = col[4].string.strip()
# 			column_6 = col[5].string.strip()
# 			column_7 = col[6].string.strip()
# 			column_8 = col[7].string.strip()
# 			column_9 = col[8].string.strip()
# 			column_10 = col[9].string.strip()
# 			column_11 = col[10].string.strip()
#
# 			#Add Data to columns
# 			#Adding data only if able to read all of the columns
# 			rank.append(column_1)
# 			gname.append(column_2)
# 			platform.append(column_3)
# 			year.append(column_4)
# 			genre.append(column_5)
# 			publisher.append(column_6)
# 			sales_na.append(column_7)
# 			sales_eu.append(column_8)
# 			sales_jp.append(column_9)
# 			sales_ot.append(column_10)
# 			sales_gl.append(column_11)
#
# 			rec_count += 1
#
# 		except:
# 			continue
#
# columns = {'rank': rank, 'name': gname, 'platform': platform, 'year': year, 'genre': genre, 'publisher': publisher, 'NA_Sales':sales_na, 'EU_Sales': sales_eu,'JP_Sales': sales_jp,'Other_Sales':sales_ot, 'Global_Sales':sales_gl }
# print rec_count
# df = pd.DataFrame(columns)
# df = df[['Rank','Name','Platform','Year','Genre','Publisher','NA_Sales','EU_Sales','JP_Sales','Other_Sales','Global_Sales']]
# del df.index.name
# df.to_csv("vgsales.csv",sep=",",encoding='utf-8')

# %%
import pandas as pd

# %%
df=pd.read_csv('/Users/samanthafalk/class-GA/week-08/3.1-group-eda/vgsales.csv')

# %%
df.head()
# Out:
#    Rank                      Name Platform    Year         Genre Publisher  \
# 0     1                Wii Sports      Wii  2006.0        Sports  Nintendo
# 1     2         Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 2     3            Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3     4         Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 4     5  Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.49     29.02      3.77         8.46         82.74
# 1     29.08      3.58      6.81         0.77         40.24
# 2     15.85     12.88      3.79         3.31         35.82
# 3     15.75     11.01      3.28         2.96         33.00
# 4     11.27      8.89     10.22         1.00         31.37

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16598 entries, 0 to 16597
# Data columns (total 11 columns):
# Rank            16598 non-null int64
# Name            16598 non-null object
# Platform        16598 non-null object
# Year            16327 non-null float64
# Genre           16598 non-null object
# Publisher       16540 non-null object
# NA_Sales        16598 non-null float64
# EU_Sales        16598 non-null float64
# JP_Sales        16598 non-null float64
# Other_Sales     16598 non-null float64
# Global_Sales    16598 non-null float64
# dtypes: float64(6), int64(1), object(4)
# memory usage: 1.4+ MB

# %%
df['Name'].value_counts()
# Out:
# Need for Speed: Most Wanted                             12
# Ratatouille                                              9
# FIFA 14                                                  9
# LEGO Marvel Super Heroes                                 9
# Madden NFL 07                                            9
# LEGO Star Wars II: The Original Trilogy                  8
# Cars                                                     8
# FIFA 15                                                  8
# Angry Birds Star Wars                                    8
# Lego Batman 3: Beyond Gotham                             8
# Terraria                                                 8
# LEGO Harry Potter: Years 5-7                             8
# Madden NFL 08                                            8
# The LEGO Movie Videogame                                 8
# LEGO Jurassic World                                      8
# Monopoly                                                 8
# FIFA Soccer 13                                           8
# LEGO The Hobbit                                          8
# Need for Speed Carbon                                    7
# LEGO The Lord of the Rings                               7
# The Amazing Spider-Man 2 (2014)                          7
# Harry Potter and the Half-Blood Prince                   7
# Major League Baseball 2K11                               7
# Surf's Up                                                7
# FIFA Soccer 08                                           7
# Harry Potter and the Order of the Phoenix                7
# Skylanders: SuperChargers                                7
# LEGO Indiana Jones: The Original Adventures              7
# Pro Evolution Soccer 2012                                7
# Star Wars The Clone Wars: Republic Heroes                7
#                                                         ..
# Project X Zone                                           1
# A Vampyre Story                                          1
# Wayne Gretzky's 3D Hockey                                1
# Halo: Reach                                              1
# ESPN Extreme Games                                       1
# Tournament Pool                                          1
# Petz Rescue: Ocean Patrol                                1
# Uncharted 2: Among Thieves                               1
# MAPLUS: Portable Navi                                    1
# Boing! Docomodake DS                                     1
# Jampack Volume 12                                        1
# EverBlue 2                                               1
# Pong / Asteroids / Yars' Revenge                         1
# Power Rangers: Ninja Storm                               1
# Mario Kart 8                                             1
# WCW/nWo Revenge                                          1
# Hakuouki: Zuisouroku Portable                            1
# Gitaroo Man Lives!                                       1
# Rush 2: Extreme Racing USA                               1
# Pengo                                                    1
# Spy Fox in Dry Cereal                                    1
# Jojo's Bizarre Adventure                                 1
# Dragon Ball GT: Final Bout                               1
# Pac-Man Party                                            1
# Cars Toon: Mater's Tall Tales                            1
# Shin Megami Tensei: Devil Survivor                       1
# The Legend of Zelda: The Minish Cap                      1
# Sonic the Hedgehog 2 (8-bit)                             1
# Even in a Game Listen to Me Girls. I Am Your Father!     1
# Bomberman 64: The Second Attack!                         1
# Name: Name, dtype: int64

# %%
df['Platform'].unique()
# Out:
# array(['Wii', 'NES', 'GB', 'DS', 'X360', 'PS3', 'PS2', 'SNES', 'GBA',
#        '3DS', 'PS4', 'N64', 'PS', 'XB', 'PC', '2600', 'PSP', 'XOne', 'GC',
#        'WiiU', 'GEN', 'DC', 'PSV', 'SAT', 'SCD', 'WS', 'NG', 'TG16', '3DO',
#        'GG', 'PCFX'], dtype=object)

# %% [markdown]
# 25-75 percentile

# %%
df.loc[df['Platform'] == 'PC']
# Out:
#         Rank                                               Name Platform  \
# 83        84                                         The Sims 3       PC
# 137      138                                  World of Warcraft       PC
# 181      182                                         Diablo III       PC
# 194      195                         Microsoft Flight Simulator       PC
# 217      218                     StarCraft II: Wings of Liberty       PC
# 267      268                     Warcraft II: Tides of Darkness       PC
# 281      282                                          Half-Life       PC
# 288      289             World of Warcraft: The Burning Crusade       PC
# 310      311                        The Elder Scrolls V: Skyrim       PC
# 328      329                                The Sims: Unleashed       PC
# 353      354                             Doom II: Hell on Earth       PC
# 456      457                                 The Sims: Vacation       PC
# 473      474                              The Sims: Livin Large       PC
# 478      479                                         The Sims 4       PC
# 479      480                        Star Wars: The Old Republic       PC
# 511      512                       Command & Conquer: Red Alert       PC
# 521      522                                               Myst       PC
# 533      534                                      Battlefield 3       PC
# 635      636                          Riven: The Sequel to Myst       PC
# 648      649                                     Theme Hospital       PC
# 653      655                                           Monopoly       PC
# 665      667                                        Half-Life 2       PC
# 691      693                                       Guild Wars 2       PC
# 694      696                                     Tomb Raider II       PC
# 755      757                              The Sims: House Party       PC
# 765      767                                       SimCity 2000       PC
# 799      801                       World of Warcraft: Cataclysm       PC
# 805      807                                     Sim Theme Park       PC
# 806      808                            Warcraft: Orcs & Humans       PC
# 874      876                             Star Wars: Dark Forces       PC
# ...      ...                                                ...      ...
# 16420  16423          Winning Eleven: Pro Evolution Soccer 2007       PC
# 16433  16436                             Clive Barker's Jericho       PC
# 16436  16439                                            Worms 2       PC
# 16444  16447                        Madagascar: Escape 2 Africa       PC
# 16447  16450                           Legacy of Kain: Defiance       PC
# 16449  16452                    King's Bounty: Armored Princess       PC
# 16459  16462                               Rugby World Cup 2015       PC
# 16474  16477                  Total War Attila: Tyrants & Kings       PC
# 16479  16482                Agatha Christie: Peril at End House       PC
# 16483  16486                                    Hospital Tycoon       PC
# 16491  16494                                   Summer Athletics       PC
# 16501  16504  Transformers: War for Cybertron (XBox 360, PS3...       PC
# 16508  16511                          The Rise of the Argonauts       PC
# 16509  16512                                              Trine       PC
# 16511  16514                                     Pony Friends 2       PC
# 16513  16516                                    Deal or No Deal       PC
# 16532  16535                            STORM: Frontline Nation       PC
# 16536  16539                         Patrician IV: Gold Edition       PC
# 16537  16540                    Transformers: Fall of Cybertron       PC
# 16539  16542                          Spore Galactic Adventures       PC
# 16540  16543                                            15 Days       PC
# 16543  16546                             Driving Simulator 2011       PC
# 16545  16548  The Treasures of Mystery Island 3 Pack - Save ...       PC
# 16547  16550                                    Bookworm Deluxe       PC
# 16555  16558              Codename: Panzers Complete Collection       PC
# 16558  16561                          Pro Evolution Soccer 2008       PC
# 16566  16569                                     End of Nations       PC
# 16577  16580                                          Damnation       PC
# 16585  16588                                             Breach       PC
# 16591  16594                                Myst IV: Revelation       PC
#
#          Year         Genre                     Publisher  NA_Sales  EU_Sales  \
# 83     2009.0    Simulation               Electronic Arts      0.98      6.42
# 137    2004.0  Role-Playing                    Activision      0.07      6.21
# 181    2012.0  Role-Playing                    Activision      2.43      2.15
# 194    1996.0    Simulation        Microsoft Game Studios      3.22      1.69
# 217    2010.0      Strategy                    Activision      2.56      1.68
# 267    1995.0      Strategy                    Activision      1.70      2.27
# 281    1997.0       Shooter                 Vivendi Games      4.03      0.00
# 288    2007.0  Role-Playing                    Activision      2.57      1.52
# 310    2011.0  Role-Playing            Bethesda Softworks      1.15      2.09
# 328    2002.0    Simulation               Electronic Arts      2.03      1.56
# 353    1994.0       Shooter            Virgin Interactive      2.05      1.40
# 456    2002.0    Simulation               Electronic Arts      1.72      1.21
# 473    2000.0          Misc               Electronic Arts      1.67      1.18
# 478    2014.0    Simulation               Electronic Arts      0.96      1.72
# 479    2011.0  Role-Playing               Electronic Arts      1.58      1.01
# 511    1996.0      Strategy            Virgin Interactive      1.37      1.34
# 521    1994.0     Adventure                       Red Orb      0.02      2.79
# 533    2011.0       Shooter               Electronic Arts      0.89      1.43
# 635    1997.0     Adventure                       Red Orb      1.52      0.82
# 648    1997.0      Strategy               Electronic Arts      2.30      0.10
# 653    1994.0          Misc            Hasbro Interactive      1.49      0.81
# 665    2004.0       Shooter                 Vivendi Games      2.28      0.02
# 691    2012.0        Action                        NCSoft      0.95      1.06
# 694    1997.0        Action             Eidos Interactive      0.91      1.25
# 755    2001.0    Simulation               Electronic Arts      1.23      0.83
# 765    1992.0    Simulation                         Maxis      1.20      0.84
# 799    2010.0  Role-Playing                    Activision      1.77      0.32
# 805    1998.0      Strategy               Electronic Arts      2.04      0.04
# 806    1994.0      Strategy                    Activision      0.89      1.08
# 874    1994.0       Shooter                     LucasArts      1.09      0.77
# ...       ...           ...                           ...       ...       ...
# 16420  2006.0        Sports  Konami Digital Entertainment      0.00      0.01
# 16433  2007.0       Shooter                   Codemasters      0.00      0.01
# 16436  1997.0      Strategy                    Microprose      0.00      0.01
# 16444  2008.0        Action                    Activision      0.01      0.00
# 16447  2003.0        Action             Eidos Interactive      0.00      0.01
# 16449  2009.0  Role-Playing                    1C Company      0.00      0.01
# 16459  2015.0        Sports                       Ubisoft      0.00      0.01
# 16474  2016.0      Strategy                    Koch Media      0.00      0.01
# 16479  2009.0     Adventure            JoWood Productions      0.00      0.01
# 16483  2007.0      Strategy                   Codemasters      0.00      0.01
# 16491  2008.0        Sports             DTP Entertainment      0.00      0.01
# 16501  2010.0       Shooter                    Activision      0.01      0.00
# 16508  2008.0  Role-Playing                   Codemasters      0.00      0.01
# 16509  2009.0        Action                       Nobilis      0.00      0.01
# 16511  2009.0    Simulation             Eidos Interactive      0.00      0.01
# 16513  2006.0          Misc        Focus Home Interactive      0.00      0.01
# 16532  2011.0      Strategy                       Unknown      0.00      0.01
# 16536  2011.0          Misc                 Kalypso Media      0.00      0.01
# 16537  2012.0        Action                    Activision      0.01      0.00
# 16539  2009.0      Strategy               Electronic Arts      0.00      0.01
# 16540  2009.0     Adventure             DTP Entertainment      0.00      0.01
# 16543  2011.0        Racing                           NaN      0.00      0.01
# 16545  2011.0        Puzzle                       Unknown      0.01      0.00
# 16547  2006.0        Puzzle                  PopCap Games      0.01      0.00
# 16555  2016.0      Strategy                  Nordic Games      0.00      0.01
# 16558  2007.0        Sports  Konami Digital Entertainment      0.00      0.01
# 16566  2012.0      Strategy                  Trion Worlds      0.01      0.00
# 16577  2009.0       Shooter                   Codemasters      0.00      0.01
# 16585  2011.0       Shooter                     Destineer      0.01      0.00
# 16591  2004.0     Adventure                       Ubisoft      0.01      0.00
#
#        JP_Sales  Other_Sales  Global_Sales
# 83         0.00         0.71          8.11
# 137        0.00         0.00          6.28
# 181        0.00         0.62          5.20
# 194        0.00         0.20          5.12
# 217        0.00         0.59          4.83
# 267        0.00         0.23          4.21
# 281        0.09         0.00          4.12
# 288        0.00         0.00          4.09
# 310        0.00         0.64          3.88
# 328        0.00         0.17          3.76
# 353        0.00         0.16          3.61
# 456        0.00         0.14          3.07
# 473        0.00         0.13          2.99
# 478        0.00         0.29          2.97
# 479        0.00         0.38          2.97
# 511        0.00         0.14          2.85
# 521        0.00         0.00          2.81
# 533        0.00         0.48          2.79
# 15996      0.00         0.00          0.01
# 16087      0.01         0.00          0.01
# 16097      0.00         0.00          0.01
# 16121      0.00         0.00          0.01
# 16151      0.01         0.00          0.01
# 16174      0.00         0.00          0.01
# 16190      0.00         0.00          0.01
# 16210      0.00         0.00          0.01
# 16218      0.01         0.00          0.01
# 16227      0.01         0.00          0.01
# 16253      0.01         0.00          0.01
# 16284      0.00         0.00          0.01
# 16310      0.01         0.00          0.01
# 16338      0.01         0.00          0.01
# 16365      0.00         0.00          0.01
# 16417      0.00         0.00          0.01
# 16428      0.00         0.00          0.01
# 16437      0.00         0.00          0.01
# 16458      0.01         0.00          0.01
# 16465      0.01         0.00          0.01
# 16473      0.01         0.00          0.01
# 16486      0.01         0.00          0.01
# 16488      0.01         0.00          0.01
# 16517      0.00         0.00          0.01
# 16552      0.01         0.00          0.01
# 16573      0.00         0.00          0.01
# 16574      0.01         0.00          0.01
# 16581      0.00         0.00          0.01
#
# [1325 rows x 11 columns]

# %%
PSdf= df.loc[df['Platform'].isin(['PS','PS2','PS3','PS4']) ]

# %%
PSdf['Platform'].value_counts()
# Out:
# PS2    2161
# PS3    1329
# PS     1196
# PS4     336
# Name: Platform, dtype: int64

# %%
PSdf['Year'].value_counts()
# Out:
# 2008.0    330
# 2007.0    304
# 2002.0    300
# 2006.0    286
# 2001.0    276
# 2005.0    260
# 2003.0    259
# 2004.0    259
# 2009.0    258
# 1998.0    248
# 2000.0    241
# 2011.0    223
# 2010.0    219
# 2015.0    211
# 1999.0    200
# 1997.0    188
# 2014.0    183
# 1996.0    164
# 2012.0    148
# 2013.0    143
# 2016.0    139
# 1995.0     99
# 1994.0     17
# 2017.0      1
# Name: Year, dtype: int64

# %%
PSdf
# Out:
#         Rank                                               Name Platform  \
# 16        17                                 Grand Theft Auto V      PS3
# 17        18                      Grand Theft Auto: San Andreas      PS2
# 24        25                        Grand Theft Auto: Vice City      PS2
# 28        29                             Gran Turismo 3: A-Spec      PS2
# 33        34                          Call of Duty: Black Ops 3      PS4
# 34        35                         Call of Duty: Black Ops II      PS3
# 37        38                     Call of Duty: Modern Warfare 3      PS3
# 38        39                               Grand Theft Auto III      PS2
# 40        41                            Call of Duty: Black Ops      PS3
# 44        45                                 Grand Theft Auto V      PS4
# 47        48                                     Gran Turismo 4      PS2
# 52        53                                       Gran Turismo       PS
# 54        55                                     Gran Turismo 5      PS3
# 55        56                     Call of Duty: Modern Warfare 2      PS3
# 56        57                                Grand Theft Auto IV      PS3
# 66        67                                  Final Fantasy VII       PS
# 67        68                               Call of Duty: Ghosts      PS3
# 69        70                                     Gran Turismo 2       PS
# 77        78                                            FIFA 16      PS4
# 82        83                                     FIFA Soccer 13      PS3
# 86        87                                    Final Fantasy X      PS2
# 87        88                                 Final Fantasy VIII       PS
# 92        93                       Star Wars Battlefront (2015)      PS4
# 93        94                     Call of Duty: Advanced Warfare      PS4
# 95        96             Crash Bandicoot 2: Cortex Strikes Back       PS
# 103      104                                      Battlefield 3      PS3
# 104      105                         Need for Speed Underground      PS2
# 105      106                                           Tekken 3       PS
# 82         0.13         2.01          8.24
# 86         2.73         0.33          8.05
# 87         3.63         0.23          7.86
# 92         0.22         1.23          7.67
# 93         0.14         1.37          7.60
# 95         1.31         0.31          7.58
# 103        0.35         1.10          7.23
# 104        0.08         1.02          7.20
# 105        1.40         0.29          7.16
# 106        1.42         0.28          7.13
# 109        0.24         1.10          6.96
# ...         ...          ...           ...
# 16419      0.01         0.00          0.01
# 16422      0.01         0.00          0.01
# 16441      0.01         0.00          0.01
# 16446      0.01         0.00          0.01
# 16450      0.00         0.00          0.01
# 16451      0.01         0.00          0.01
# 16454      0.01         0.00          0.01
# 16455      0.01         0.00          0.01
# 16466      0.01         0.00          0.01
# 16469      0.01         0.00          0.01
# 16480      0.01         0.00          0.01
# 16489      0.00         0.00          0.01
# 16492      0.01         0.00          0.01
# 16502      0.01         0.00          0.01
# 16504      0.01         0.00          0.01
# 16506      0.00         0.00          0.01
# 16510      0.01         0.00          0.01
# 16518      0.00         0.00          0.01
# 16521      0.01         0.00          0.01
# 16524      0.01         0.00          0.01
# 16541      0.01         0.00          0.01
# 16550      0.01         0.00          0.01
# 16551      0.01         0.00          0.01
# 16554      0.00         0.00          0.01
# 16559      0.01         0.00          0.01
# 16561      0.01         0.00          0.01
# 16570      0.00         0.00          0.01
# 16572      0.01         0.00          0.01
# 16580      0.01         0.00          0.01
# 16595      0.00         0.00          0.01
#
# [5022 rows x 11 columns]

# %% [markdown]
# Games with established pasts tend to perform better than new games on play station consoles (possibly all consoles)

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
df=pd.read_csv("vgsales.csv")
df=df[pd.notnull(df["Year"])]
df=df.drop_duplicates()
df = df[(df['Year']<2016) & (df['Year']>=2005)]

# %%
def handheld_bin(platform):
    dictionary={'3DS': 'Yes',
                'DC': 'No',
                'DS': 'Yes',
                'GBA': 'Yes',
                'GC': 'No',
                'PC': 'No',
                'PS2': 'No',
                'PS3': 'No',
                'PS4': 'No',
                'PSP': 'Yes',
                'PSV': 'Yes',
                'Wii': 'No',
                'WiiU': 'Yes',
                'X360': 'No',
                'XB': 'No',
                'XOne': 'No'}
    return dictionary[platform]
def platform_bin(platform):
    dictionary={'3DS': 'Nintendo',
                'DC': 'Sega',
                'DS': 'Nintendo',
                'GBA': 'Nintendo',
                'GC': 'Nintendo',
                'PC': 'PC',
                'PS2': 'Sony',
                'PS3': 'Sony',
                'PS4': 'Sony',
                'PSP': 'Sony',
                'PSV': 'Sony',
                'Wii': 'Nintendo',
                'WiiU': 'Nintendo',
                'X360': 'Microsoft',
                'XB': 'Microsoft',
                'XOne': 'Microsoft'}
    return dictionary[platform]
df["Handheld"]=df["Platform"].apply(lambda x: handheld_bin(x))
df["Platform"]=df["Platform"].apply(lambda x: platform_bin(x))
df.reset_index(inplace=True,drop=True)
print "Checking to see if we had any missing values"
print df["Handheld"].value_counts().sum()
print df["Handheld"].value_counts()
print df["Platform"].value_counts().sum()
print df["Platform"].value_counts()
print "Total Number of Rows: "+str(len(df))
# Out:
# Checking to see if we had any missing values
# 10807
# No     6389
# Yes    4418
# Name: Handheld, dtype: int64
# 10807
# Nintendo     4317
# Sony         4097
# Microsoft    1631
# PC            760
# Sega            2
# Name: Platform, dtype: int64
# Total Number of Rows: 10807

# %%
#This cell will get us a list of all released titles, and a list of information of the platforms
# they were released on and the respective global sales by system
names=df["Name"].unique()
titles_dictionary={}
indices=df["Name"].index
#titles_dictionary will assign each name in 'names' a list of lists consisting of ["Platform","Global Sales"]
for name in names:
    titles_dictionary[name]=[]
for index in indices:
    row=df.iloc[index].copy()
    temp=titles_dictionary[row["Name"]]
    temp.append([row["Platform"],row["Global_Sales"]])
    titles_dictionary[name]=temp

# %%
df = df[(df['Platform'] != 'Sega')]

# %%
df.head()
# Out:
#    Rank                   Name  Platform    Year     Genre Publisher  \
# 0     1             Wii Sports  Nintendo  2006.0    Sports  Nintendo
# 1     3         Mario Kart Wii  Nintendo  2008.0    Racing  Nintendo
# 2     4      Wii Sports Resort  Nintendo  2009.0    Sports  Nintendo
# 3     7  New Super Mario Bros.  Nintendo  2006.0  Platform  Nintendo
# 4     8               Wii Play  Nintendo  2006.0      Misc  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales Handheld
# 0     41.49     29.02      3.77         8.46         82.74       No
# 1     15.85     12.88      3.79         3.31         35.82       No
# 2     15.75     11.01      3.28         2.96         33.00       No
# 3     11.38      9.23      6.50         2.90         30.01      Yes
# 4     14.03      9.20      2.93         2.85         29.02       No

# %%
#Create a function that takes in a list of platforms and sales, and creates a dictionary with keys corresponding
# to the platform and global sales organized from best to worst in terms of sales; best global sales gets 1
# It will output a dictionary with values of lists  {1: [[PS3:1,100,000],[...]],2: [[PS2:750,000],[...]]}
def rank_systems(dictionary):
    return_dict={}
    for key in dictionary:
        temp=dictionary[key]
        temp.sort(key=(lambda x: x[1]))
        temp.reverse()
        for i in range(len(temp)):
            l_temp=[]
            if str(len(temp)+1) in return_dict.keys():
                l_temp=return_dict[str(i+1)]
            l_temp.append(temp[i])
            return_dict[str(i+1)]=l_temp
    return return_dict
def rank_sales(dictionary):
    return_dict={}
    for key in dictionary:
        temp=dictionary[key]
        temp.sort(key=(lambda x: x[1]))
        temp.reverse()
        for i in range(len(temp)):
            l_temp=[]
            if str(len(temp)+1) in return_dict.keys():
                l_temp=return_dict[str(i+1)]
            l_temp.append(temp[i][1])
            return_dict[str(i+1)]=l_temp
    return return_dict
systems_dictionary=rank_systems(titles_dictionary)
sales_dictionary=rank_sales(titles_dictionary)
keys=[key for key in sales_dictionary.keys()]
xs=[int(key) for key in keys]
ys=[np.mean(sales_dictionary[key]) for key in keys]
sns.barplot(x=xs, y=ys)
plt.show()

# %%
#Goal is to see that if you did best on console 'X', what other platforms looked like
# Use dictionary again, but filter so '1' is only console X, and '1' is non-console x
def rank_system_sales(dictionary,system):
    return_dict={}
    for key in dictionary:
        temp=dictionary[key]
        temp.sort(key=(lambda x: x[1]))
        temp.reverse()
        if temp[0][0]==system:
            for i in range(len(temp)):
                l_temp=[]
                if str(len(temp)+1) in return_dict.keys():
                    l_temp=return_dict[str(i+1)]
                l_temp.append(temp[i][1])
                return_dict[str(i+1)]=l_temp
    return return_dict
def rank_system_sales_versus(dictionary,system,competitor):
    return_dict={}
    for key in dictionary:
        temp=dictionary[key]
        if len(temp)>1:
            temp.sort(key=(lambda x: x[1]))
            temp.reverse()
            if temp[0][0]==system:
                if temp[1][0]==competitor:
                    for i in range(len(temp)):
                        l_temp=[]
                        if str(len(temp)+1) in return_dict.keys():
                            l_temp=return_dict[str(i+1)]
                        l_temp.append(temp[i][1])
                        return_dict[str(i+1)]=l_temp
    return return_dict

# %%
### Change these values to see the companies you want
primary="Microsoft"
competitor="Microsoft"
system_sales_dictionary=rank_system_sales(titles_dictionary,primary)
system_sales_versus_dictionary=rank_system_sales_versus(titles_dictionary,primary,competitor)
keys=[key for key in system_sales_dictionary.keys()]
xs=[int(key) for key in keys]
ys=[np.mean(system_sales_dictionary[key]) for key in keys]
sns.barplot(x=xs, y=ys)
plt.title("%s Sales" %primary)
plt.ylabel("Sales Volume in Millions")
plt.xticks(range(1),[primary])
plt.show()
keys=[key for key in system_sales_versus_dictionary.keys()]
xs=[int(key) for key in keys]
ys=[np.mean(system_sales_versus_dictionary[key]) for key in keys]
sns.barplot(x=xs, y=ys)
plt.title("%s"%primary+" vs "+"%s"%competitor+" Sales" )
plt.ylabel("Sales Volume in Millions")
plt.xticks(range(2),[primary,competitor])
plt.show()

# %%
df.head()
# Out:
#    Rank                   Name  Platform    Year     Genre Publisher  \
# 0     1             Wii Sports  Nintendo  2006.0    Sports  Nintendo
# 1     3         Mario Kart Wii  Nintendo  2008.0    Racing  Nintendo
# 2     4      Wii Sports Resort  Nintendo  2009.0    Sports  Nintendo
# 3     7  New Super Mario Bros.  Nintendo  2006.0  Platform  Nintendo
# 4     8               Wii Play  Nintendo  2006.0      Misc  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales Handheld
# 0     41.49     29.02      3.77         8.46         82.74       No
# 1     15.85     12.88      3.79         3.31         35.82       No
# 2     15.75     11.01      3.28         2.96         33.00       No
# 3     11.38      9.23      6.50         2.90         30.01      Yes
# 4     14.03      9.20      2.93         2.85         29.02       No

# %%
#group by name, year, genre and platform, summing up all sales
company_game = df.groupby(['Name','Year','Genre','Platform_CO'])['Global_Sales'].sum().to_frame()
company_game.reset_index(inplace = True)
# group by platform_co year and genre
company_genre = company_game.groupby(['Platform_CO','Year','Genre'])['Global_Sales'].agg({len,sum})
company_genre.reset_index(inplace = True)

#group by platform_co and year to find sales and count of all platform_co by year
company = company_game.groupby(['Platform_CO','Year'])['Global_Sales'].agg({sum,len})
company.reset_index(inplace = True)
company['avg'] = (company['sum'] / company['len']).round(2)
#plotting
plt.subplots(figsize =(15,7))
sns.pointplot(x='Year',y='avg',data=company[company['Platform_CO'] != 'Sega'], hue='Platform_CO')
plt.title("Average Sales/Game (mn) for Platform Company by Year",fontsize = 18)
plt.xlabel("Year",fontsize=16)
plt.ylabel("Average Sales/Game (mn)",fontsize=16)
plt.ylim(0,1.4)
plt.subplots(figsize =(15,7))
sns.pointplot(x='Year',y='len',data=company[company['Platform_CO'] != 'Sega'], hue='Platform_CO')
plt.title("Number of Games for Platform Company by Year",fontsize = 18)
plt.xlabel("Year",fontsize=16)
plt.ylabel("Number of Games",fontsize=16)
plt.ylim(0,800);

# %%
# %matplotlib inline 

import pandas as pd
import numpy as np
from sklearn import cluster, metrics
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.neighbors import KNeighborsClassifier
from scipy.cluster.hierarchy import dendrogram, linkage, cophenet, fcluster
from scipy.spatial.distance import pdist
import matplotlib.pyplot as plt
import matplotlib
import seaborn as sns
matplotlib.style.use('ggplot')

# %% [markdown]
# ## 1. Format the Data

# %%
airportdf=pd.read_csv('/Users/samanthafalk/class-GA/week-seven/4.2-lab-hierarchical-clustering/assets/datasets/airport2.csv')

# %%
airportdf.head()
# Out:
#   Airport  Year  Departure Cancellations  Arrival Cancellations  \
# 0     ABQ  2004                      242                    235
# 1     ABQ  2005                      221                    190
# 2     ABQ  2006                      392                    329
# 3     ABQ  2007                      366                    304
# 4     ABQ  2008                      333                    300
#
#    Departure Diversions  Arrival Diversions
# 0                    71                  46
# 1                    61                  33
# 2                    71                 124
# 3                   107                  45
# 4                    79                  42

# %% [markdown]
# Convert the class labels, in this case the airports, to numeric. *Remember*, we've truncated the airport dataset for simplicty to make this part easy!

# %%
airportnames=airportdf['Airport'].unique().tolist()

# %%
airportnames
# Out:
# ['ABQ', 'ANC', 'ATL']

# %%
len(airportnames)
# Out:
# 3

# %%
airportnames.index('ABQ')
# Out:
# 0

# %%
airportdf['Airport']=airportdf['Airport'].apply(lambda x: airportnames.index(x))

# %%
airportdf.head(12)
# Out:
#     Airport  Year  Departure Cancellations  Arrival Cancellations  \
# 0         0  2004                      242                    235
# 1         0  2005                      221                    190
# 2         0  2006                      392                    329
# 3         0  2007                      366                    304
# 4         0  2008                      333                    300
# 5         0  2009                      192                    162
# 6         0  2010                      222                    177
# 7         0  2011                      345                    294
# 8         0  2012                      237                    181
# 9         0  2013                      232                    212
# 10        0  2014                      315                    274
# 11        1  2004                      473                    532
#
#     Departure Diversions  Arrival Diversions
# 0                     71                  46
# 1                     61                  33
# 2                     71                 124
# 3                    107                  45
# 4                     79                  42
# 5                     74                  26
# 6                     71                  50
# 7                     77                  61
# 8                     65                  60
# 9                     62                  46
# 10                    66                  37
# 11                    73                  30

# %% [markdown]
# ## 2. Plot the data

# %%
airportdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33 entries, 0 to 32
# Data columns (total 6 columns):
# Airport                    33 non-null int64
# Year                       33 non-null int64
# Departure Cancellations    33 non-null int64
# Arrival Cancellations      33 non-null int64
# Departure Diversions       33 non-null int64
# Arrival Diversions         33 non-null int64
# dtypes: int64(6)
# memory usage: 1.6 KB

# %%
sns.heatmap(airportdf.corr(),annot=True)

# %%
sns.pairplot(airportdf)

# %% [markdown]
# ## 3.  Perform a K-Means Clustering

# %% [markdown]
# #### 3.1 Split the dataset into the attribute data and class labels

# %%
#X_scaled = preprocessing.MinMaxScaler().fit_transform(df[cols])

# %%
y=airportdf.iloc[:,0]

# %%
X=airportdf.iloc[:,1:]

# %% [markdown]
# #### 3.2 Conduct the k-means clustering

# %%
k=3

# %% [markdown]
# #### 3.3 Compute the labels and centroids

# %% [markdown]
# #### 3.4 Format the resulting predicted "y" variables and check the accuracy score, classification report, and confusion matrix

# %% [markdown]
# **Question**: What are we understand from this these performance metrics?

# %% [markdown]
# ## 4. Extra Trees Classifier

# %% [markdown]
# ## 5. KNN Classifier

# %% [markdown]
# ## 6. Hierarchical Clustering

# %% [markdown]
# #### 6.1 Create the linkage for clustering

# %% [markdown]
# #### 6.2 Plot the Denrogram

# %% [markdown]
# ## Extra Trees Classifier

# %% [markdown]
# ## KNN Classifier
